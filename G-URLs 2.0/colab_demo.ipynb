# %%
# Install all required packages
# !pip install flask dnspython requests scikit-learn xgboost joblib pyngrok -q
print("Done installing")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 12.8 MB/s eta 0:00:00
# Done installing

# %%
# Clone your GitHub repository
# !git clone https://github.com/Oyewumi-Gbemisola/Oyewumi-Gbemisola-Multilayer-Detection-Architecture-for-Malicious-Domain-and-Web-Traffic-Analysis.git

# %cd Oyewumi-Gbemisola-Multilayer-Detection-Architecture-for-Malicious-Domain-and-Web-Traffic-Analysis/URL\ Analyzer

print("Done cloning")
# Out:
# Cloning into 'Oyewumi-Gbemisola-Multilayer-Detection-Architecture-for-Malicious-Domain-and-Web-Traffic-Analysis'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 103 (delta 10), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (103/103), 11.60 MiB | 10.78 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# [Errno 2] No such file or directory: 'Oyewumi-Gbemisola-Multilayer-Detection-Architecture-for-Malicious-Domain-and-Web-Traffic-Analysis/URL Analyzer'
# /content
# Done cloning

# %%
# Start the app with a public link
from pyngrok import ngrok
from threading import Thread
import subprocess

public_url = ngrok.connect(5000)
print(f"G-URLs 2.0 is live at: {public_url}")

subprocess.Popen(["python", "app.py"])
# Out:
# ERROR:pyngrok.process.ngrok:t=2026-05-01T23:26:59+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ERROR:pyngrok.process.ngrok:t=2026-05-01T23:26:59+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ...
